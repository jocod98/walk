# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\smart_crosswalk\\analysis'

# %%
data_path = '../data/handled/data_for_tableau.xlsx'

# %%
data = pd.read_excel(data_path)

# %%
data
# Out:
#        Unnamed: 0  index    번호       현장명   방향                   일시  신호횟수  \
# 0               0      0     1  자운학교앞(5)    동  2021-08-01 00:00:00    23
# 1               1      1     2  자운학교앞(5)  NaN  2021-08-01 01:00:00    24
# 2               2      2     3  자운학교앞(5)  NaN  2021-08-01 02:00:00    24
# 3               3      3     4  자운학교앞(5)  NaN  2021-08-01 03:00:00    24
# 4               4      4     5  자운학교앞(5)  NaN  2021-08-01 04:00:00    24
# ...           ...    ...   ...       ...  ...                  ...   ...
# 40482       40482   2871  2872   파주병원(4)  NaN  2022-09-30 19:00:00    29
# 40483       40483   2872  2873   파주병원(4)  NaN  2022-09-30 20:00:00    30
# 40484       40484   2873  2874   파주병원(4)  NaN  2022-09-30 21:00:00    30
# 40485       40485   2874  2875   파주병원(4)  NaN  2022-09-30 22:00:00    30
# 40486       40486   2875  2876   파주병원(4)  NaN  2022-09-30 23:00:00    31
#
#        운영시간  녹색시간  통과보행자  ...  연장_횟수  연장_시간  연장_보행자  교통약자_목발  교통약자_휠체어  \
# ...
